# %% [markdown]
# #Các phương pháp đã cài đặt

# %%
# !git clone https://github.com/t-hin241/CS523
# Out:
# Cloning into 'CS523'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 43 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
import sys

path_m = "/content/CS523/Seminar"
sys.path.insert(0,path_m)

# %cd /content/CS523/Seminar
# Out:
# /content/CS523/Seminar

# %%
from BIT import *
from NaiveSolution import *
from segment_tree.segment_tree import *

# %% [markdown]
# #Clone and Preprocess GIS dataset

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 34.1 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 73.6 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 83.5 MB/s
# ...

# %%
# %cd /content
# !git clone https://github.com/CityScope/CSL_HCMC
# Out:
# /content
# Cloning into 'CSL_HCMC'...
# remote: Enumerating objects: 1957, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 1957 (delta 7), reused 1 (delta 1), pack-reused 1911
# Receiving objects: 100% (1957/1957), 175.89 MiB | 34.39 MiB/s, done.
# Resolving deltas: 100% (1063/1063), done.
# Checking out files: 100% (542/542), done.

# %%
import geopandas as gpd
import numpy as np

# %%
df = gpd.read_file("/content/CSL_HCMC/Data/GIS/Population/population_HCMC/population_shapefile/Population_District_Level.shp")
df
# Out:
#       Dist_Name Dist_ID     Level  Pop_2009  Pop_2010  Pop_2011  Pop_2012  \
# 0    District 1     760  District  180225.0  187435.0  187419.0  190943.0
# 1    District 3     770  District  190553.0  188945.0  190631.0  191580.0
# 2    District 4     773  District  180980.0  183261.0  184711.0  185649.0
# 3    District 6     775  District  249329.0  253474.0  254212.0  257865.0
# 4    District 7     778  District  244276.0  274828.0  268483.0  266633.0
# 5   District 10     771  District  230345.0  232450.0  236336.0  237086.0
# 6   District 11     772  District  226854.0  232536.0  236443.0  233499.0
# 7     Phu Nhuan     768  District  174535.0  175175.0  177242.0  179917.0
# 8      Tan Binh     766  District  421724.0  430436.0  434298.0  440351.0
# 9    Binh Thanh     765  District  457362.0  470054.0  484135.0  484423.0
# 10       Go Vap     764  District  522690.0  548145.0  566216.0  588606.0
# 11      Tan Phu     767  District  398102.0  407924.0  423074.0  439099.0
# ...

# %%
input = list(df.Pop_2019)
sum_st = SegmentTree(input, 'sum')
print("Total population in HCMC 2019:", sum_st.root.value)
# Out:
# Total population in HCMC 2019: 8993082.0

# %%
min_st = SegmentTree(input, 'min')
print("Min 2019 population district:", df.Dist_Name[input.index(min_st.root.value)])
# Out:
# Min 2019 population district: Can Gio

# %%
max_st = SegmentTree(input, 'max')
print("Min 2019 population district:", df.Dist_Name[input.index(max_st.root.value)])
# Out:
# Min 2019 population district: Binh Tan
